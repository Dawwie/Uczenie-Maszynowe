# %%
# Zadanie 2.1
import pandas as pd
import matplotlib.pyplot as plt

frame = pd.read_csv("data2.csv")
data_array = frame.to_numpy()

x, y = data_array[:, 3], data_array[:, 4]
plt.plot(x, 'go', y, "ro")
plt.show()  # pokaż wykres
